# %% [markdown]
# <a href="https://colab.research.google.com/github/rupyab/Airbnb-Booking-Analysis/blob/main/AirBnb_Bookings_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name:AirBnb Bookings Analysis**

# %% [markdown]
# Project Type - EDA
#
# Contribution - Individual
#
# Team Member 1 - Rupesh Bangar

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# Since 2008, guests and hosts have used Airbnb to expand on travelling possibilities and present a more unique, personalised way of experiencing the world. Today, Airbnb became one of a kind service that is used and recognized by the whole world. Data analysis on millions of listings provided through Airbnb is a crucial factor for the company. These millions of listings generate a lot of data - data that can be analysed and used for security, business decisions, understanding of customers' and providers' (hosts) behaviour and performance on the platform, guiding marketing initiatives, implementation of innovative additional services and much more. This dataset has around 49,000 observations in it with 16 columns and it is a mix of categorical and numeric values. Explore and analyse the data to discover key understandings.

# %% [markdown]
# # **GitHub Link**:

# %% [markdown]
# Name: Rupesh Bangar
#
# link: https://github.com/rupyab/Airbnb-Booking-Analysis/blob/main/README.md

# %% [markdown]
# # **Define Your Business objective**

# %% [markdown]
# Recommending marketing campaign strategies and predicting the destination neighbourhood which are in high demand.
#
# Using Exploratory Data Analysis, find out the most demanded room type, neighbourhood_group.
#
# Find the average days guests prefer to stay in single visit in different room type in varied neighbourhood_group
#
# The aim is to identify insights and patterns in the data that can help the company understand the drivers of customer retention and inform future decision-making regarding host listing, location, price and customer service and marketing strategies

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # **let's Play with EDA....**

# %% [markdown]
# # **1. Know Your Data**

# %% [markdown]
# ### Import Libraries

# %%
# import all necessary libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import folium
from folium.plugins import MarkerCluster
from folium import plugins
from folium.plugins import FastMarkerCluster
from folium.plugins import HeatMap
from scipy.stats import pearsonr

# %% [markdown]
# ### Dataset Loading...

# %% [markdown]
# **Read CSV file**

# %%
df=pd.read_csv("Airbnb NYC 2019.csv")
df
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
df.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
print('\nRows : ',df.shape[0])
print('\nColumns :', df.shape[1])
# Out:
# Rows :  48895
#
# Columns : 16

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Information
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  int64
#  1   name                            48879 non-null  object
#  2   host_id                         48895 non-null  int64
#  3   host_name                       48874 non-null  object
#  4   neighbourhood_group             48895 non-null  object
#  5   neighbourhood                   48895 non-null  object
#  6   latitude                        48895 non-null  float64
#  7   longitude                       48895 non-null  float64
#  8   room_type                       48895 non-null  object
#  9   price                           48895 non-null  int64
#  10  minimum_nights                  48895 non-null  int64
#  11  number_of_reviews               48895 non-null  int64
# ...

# %%
# Describing dataset
df.describe()
# Out:
#                  id       host_id      latitude     longitude         price  \
# count  4.889500e+04  4.889500e+04  48895.000000  48895.000000  48895.000000
# mean   1.901714e+07  6.762001e+07     40.728949    -73.952170    152.720687
# std    1.098311e+07  7.861097e+07      0.054530      0.046157    240.154170
# min    2.539000e+03  2.438000e+03     40.499790    -74.244420      0.000000
# 25%    9.471945e+06  7.822033e+06     40.690100    -73.983070     69.000000
# 50%    1.967728e+07  3.079382e+07     40.723070    -73.955680    106.000000
# 75%    2.915218e+07  1.074344e+08     40.763115    -73.936275    175.000000
# max    3.648724e+07  2.743213e+08     40.913060    -73.712990  10000.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count    48895.000000       48895.000000       38843.000000
# mean         7.029962          23.274466           1.373221
# std         20.510550          44.550582           1.680442
# ...

# %% [markdown]
# ### Duplicate Values

# %%
# Dataset Duplicate Value Count
duplicate_count = df.duplicated().sum()
duplicate_count
# Out:
# 0

# %% [markdown]
# ### Missing Values/Null Values

# %%
# Finding Null values
print("\nThe null values in each columns are as follows:\n",df.isnull().sum())
# Out:
# The null values in each columns are as follows:
#  id                                    0
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %% [markdown]
# ### What did you know about your dataset?
#
#
#
# 1.   The Dataset contains a total of 16 columns and 48895 observations in total.
#
# 2.   Minimum price is 0 USD and maximum price is 10000.
#
# 3.   Mean price is 152 USD.
#
# 4.   On average ,people stay in a room for 7 days.
#
# 5.   There are total 4 columns with null values.

# %% [markdown]
# # ***2. Understanding Your Variables***

# %%
# Columns Name
print('\nColumns :', df.columns)
# Out:
# Columns : Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365'],
#       dtype='object')

# %% [markdown]
# ### Variables Description

# %% [markdown]
# we get to know that some columns falls under categorical and remaining are numeriacal except one last_review comes under Date_Time category.
#
# Categorical variable : name,neighbourhood_group, neighbourhood, room_type
#
# Numerical variable : id, host_id, price, minimum_nights, number_of_reviews, reviews_per_month, calculated_host_listings_count, availability_365
#
# Date_Time variable : last_review
#
# Coordinates : latitude, longitude
#
#
# 1. ID: A unique identifier for each Airbnb listing.
# 2. Name: Name of the listing.
# 3. Host ID: A unique identifier for each Airbnb host.
# 4. host name: name of the host
# 5. Neighborhood_group: location of the Airbnb listing.
# 6. Neighborhood: Area of the Airbnb listing.
# 7. Latitude: The latitude coordinate of the listing's location.
# 8. Longitude: The longitude coordinate of the listing's location.
# 9. Room Type: The type of room available for booking, such as an entire home/apartment, private room, or shared room.
# 10. Price: The price per night for renting the Airbnb listing.
# 11. Minimum Nights: The minimum number of nights required for a booking.
# 12. Number of reviews: number of reviews
# 13. last_review: content of last review
# 14. reviews per months:number of checks per months
# 15. calculate host listing count: total count
# 16. Availability_360: The availability of the listing around the year.

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
unique_values = df.nunique()
unique_values
# Out:
# id                                48895
# name                              47905
# host_id                           37457
# host_name                         11452
# neighbourhood_group                   5
# neighbourhood                       221
# latitude                          19048
# longitude                         14718
# room_type                             3
# price                               674
# minimum_nights                      109
# number_of_reviews                   394
# last_review                        1764
# reviews_per_month                   937
# calculated_host_listings_count       47
# availability_365                    366
# dtype: int64

# %% [markdown]
# # 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Filling null values with appropriate value
df.fillna({'reviews_per_month':0},inplace=True)
df.fillna({'host_name':'Others'},inplace=True)
df.fillna({'name':'Not Found'},inplace=True)

# %%
# We can delet last reviews from dataset becuase the last reviews are from 2018 and there are more than 2000 null values
df.drop(columns='last_review', inplace=True)

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# While reading the data we have found that there are some column which are of no use for us in our case study.we have droped 1 columns(last_review).
#
# There were 1052 null vaues in review_per_month column.we cants drop this much rows so we replace this null values with 0.

# %% [markdown]
# # ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# ### Chart - 1    Map

# %%
# We are using folium library to locate location on map
Long=-73.80
Lat=40.80
locations = list(zip(df.latitude, df.longitude))

map1 = folium.Map(location=[Lat,Long], zoom_start=9)
FastMarkerCluster(data=locations).add_to(map1)
map1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Folium's ease of use and intuitive API made it simple to visualize Airbnb listings geographically. The ability to add customizable markers and pop-ups allowed for detailed display of listing information, such as price and property type. Additionally, Folium's integration with data analysis libraries like Pandas facilitated seamless handling and visualization of large datasets. Its support for various map layers and GeoJSON data enabled effective visualization of spatial patterns, such as listing density and price distribution. Overall, Folium enhanced the clarity and engagement of my analysis by providing dynamic and interactive visualizations.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the map?

# %% [markdown]
# 1. Exact location of New York City.
# 2. Nearby cities of New York.
# 3. Number of listed roons in each region.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Using Folium for Airbnb analysis provides business insights by visualizing spatial patterns and trends, such as listing density and price distribution, helping identify high-demand areas and optimize pricing strategies.

# %% [markdown]
# ### Chart - 2 Number of available rooms in different Neighborhood

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x=df.longitude,y=df.latitude,hue=df.neighbourhood_group)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A scatter plot can indeed be a suitable choice in certain cases to visualize the relationship between variables, including latitude and longitude.
#
# While scatter plots are commonly used for numerical variables, they can also be applied to geographic coordinates, such as latitude and longitude. However, it's important to note that the interpretation of the scatter plot in this case should be focused on the spatial distribution rather than a direct correlation or relationship between the variables

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# We can observe that hotel rooms are more densely populated in Brooklyn and are a lot more spread in Queens

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# This chart shows locations nearer to the prime hotspots can garner more bookings hence we try hard to list more number of demanding room type and increase overall revenue by attracting customer

# %% [markdown]
# ### *Chart - 3 Count the occurrences of each neighborhood*

# %%
# Most Number of bookings neighbourhood group wise
df['neighbourhood_group'].value_counts().plot(kind='bar', color= ['r','y','b','g'])
plt.xlabel('neighbourhood_group')
plt.ylabel('Bookings')
plt.title('Most Number of bookings')
plt.show()

# %% [markdown]
# #### 1. Why did you pick the specific chart?

# %% [markdown]
# The bar plot was chosen to visualize the neighborhood_group in the Airbnb dataset for the following reasons:
#
# Categorical Data: The neighborhood_group variable in the Airbnb dataset represents categorical data, as it consists of distinct neighborhood names. Bar plots are well-suited for visualizing the distribution or frequency of categorical variables.
#
# Count Comparison: The bar plot allows for easy comparison of the counts or frequencies of different neighborhoods. The lengths of the bars directly represent the counts, making it simple to identify neighborhoods with higher or lower numbers of listings.

# %% [markdown]
# 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Popular Neighborhoods: The bar plot reveal the neighborhoods with the highest counts i.e Manhattan, indicating the most popular or frequently listed areas in the dataset. These neighborhoods may attract more visitors or have a larger number of available accommodations.
#
# Less Common Neighborhoods: The plot also highlight neighborhoods with lower counts i.e taten island and bronx, suggesting less commonly listed or less popular areas. These neighborhoods may have fewer options for accommodations or cater to a more niche audience.
#
# Market Opportunities: Neighborhoods with low counts staten island and bronx in the bar plot represent potential market opportunities. These areas may have fewer listings, indicating potential demand for additional accommodations or untapped market segments

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Market Understanding: By visualizing the counts of each neighborhood group, the business gains insights into the distribution of hotels across different areas. This information can help in understanding the market landscape, identifying areas with high hotel density, and exploring potential opportunities for growth or expansion.
#
# Location-Based Strategies: Understanding the hotel counts in each neighborhood group allows businesses to tailor their strategies based on specific locations. For example, they can allocate marketing resources, promotional activities, or service enhancements to areas with higher hotel counts to maximize visibility and attract more customers.

# %% [markdown]
# ### Chart-4 : Top 5 Neighbourhood and bottom 5 Neighbourhood

# %%
# Top 5 neighbourhood listing
neighbourhood=df.groupby(['neighbourhood_group','neighbourhood'])['neighbourhood'].value_counts().sort_values(ascending=False).reset_index(name='total')
neighbourhood.head(5)
# Out:
#   neighbourhood_group       neighbourhood  total
# 0            Brooklyn        Williamsburg   3920
# 1            Brooklyn  Bedford-Stuyvesant   3714
# 2           Manhattan              Harlem   2658
# 3            Brooklyn            Bushwick   2465
# 4           Manhattan     Upper West Side   1971

# %%
# Top 5 neighbourhood
neighbourhood.head(5).plot(kind='bar',x='neighbourhood',y='total')
plt.xlabel('neighbourhood')
plt.ylabel('bookings')
# Out:
# Text(0, 0.5, 'bookings')

# %% [markdown]
# ####Why did you pick the specific chart?

# %% [markdown]
# This bar chart is chosen because it effectively displays and compares the total number of bookings across different neighbourhoods. It provides a clear visual representation of the data, making it easy to identify which neighbourhoods have the highest and lowest bookings

# %% [markdown]
# ####What is/are the insight(s) found from the chart?

# %% [markdown]
# From this chart, it is evident that Williamsburg and Bedford-Stuyvesant are the most popular neighbourhoods in terms of bookings, followed by Harlem, Bushwick, and Upper West Side. This insight indicates a preference pattern among customers, with Williamsburg being the most fav

# %% [markdown]
# ####Will the gained insights help create a positive business impact?

# %% [markdown]
# Yes, these insights can help in creating a positive business impact by enabling targeted marketing strategies, resource allocation, and promotional efforts in the top-performing neighbourhoods. Additionally, understanding customer preferences can help in optimizing operations and enhancing customer satisfaction in these areas.

# %% [markdown]
# ### Bottom 5 neighbourhood

# %%
neighbourhood.tail(5)
# Out:
#     neighbourhood_group   neighbourhood  total
# 216       Staten Island    Richmondtown      1
# 217       Staten Island        New Dorp      1
# 218       Staten Island  Fort Wadsworth      1
# 219       Staten Island     Willowbrook      1
# 220       Staten Island         Woodrow      1

# %%
neighbourhood.tail(5).plot(kind='bar',x='neighbourhood',y='total')
# Out:
# <Axes: xlabel='neighbourhood'>

# %% [markdown]
# #### 1. Why did you pick the specific chart?

# %% [markdown]
# The bar chart was chosen because it effectively displays categorical data, allowing for easy comparison of values across different neighborhoods. It provides a clear visual representation of the total values for each neighborhood, making it simple to identify patterns or uniformity.

# %% [markdown]
# #### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart shows that the total values for each neighborhood are identical, indicating uniformity across all the neighborhoods listed. This uniform distribution suggests that there are no significant differences or variations in the total values among these neighborhoods.

# %% [markdown]
# ####3. Will the gained insights help create a positive business impact?

# %% [markdown]
# The insights could help create a positive business impact by highlighting that resources or strategies being uniformly applied across these neighborhoods are consistent. This can be useful for ensuring equal treatment and planning purposes, knowing that no single neighborhood is outperforming or underperforming relative to the others.

# %% [markdown]
# ###Chart-5 :Top 5 host names

# %%
host=df['host_name'].value_counts().sort_values(ascending=False)
host.head(5).plot(kind='bar',color=['r','y','g','b','c'])
plt.xlabel('Host name')
plt.ylabel('Counts')
plt.title('Top 5 Host names')
# Out:
# Text(0.5, 1.0, 'Top 5 Host names')

# %% [markdown]
# Above plot shows the Top 5 host and it looks like Michael has received more listing for topping the chart. But we can't get accurate insights from that as the name may be same.

# %% [markdown]
# ### Chart-6 : Top 5 Host Id

# %%
host_id=df.groupby(['host_id','host_name'])['host_id'].value_counts().sort_values(ascending=False)
TOP=host_id.head(5)
host_id.head(5).plot(kind='bar',color=['r','y','g','b','c'])
plt.xlabel('host_id')
plt.ylabel('Counts')
plt.title('Top 5 Host names')
print("the top 5 host id's are", pd.DataFrame(TOP))
# Out:
# the top 5 host id's are                           count
# host_id   host_name
# 219517861 Sonder (NYC)      327
# 107434423 Blueground        232
# 30283594  Kara              121
# 137358866 Kazuya            103
# 16098958  Jeremy & Laura     96

# %% [markdown]
# #### Why did you pick the specific chart?

# %% [markdown]
# The bar chart was selected because it clearly demonstrates the distribution of counts among the top 5 host names. Bar charts are excellent for displaying categorical data, making it easy to compare the frequency of listings across different hosts.

# %% [markdown]
# #### What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart reveals that "Sonder (NYC)" is the most frequent host with significantly higher counts compared to the other top hosts. "Blueground" also has a substantial number of listings, but noticeably less than "Sonder (NYC)." The other three hosts ("Kara," "Kazuya," and "Jeremy & Laura") have relatively similar and lower counts.

# %% [markdown]
# #### Will the gained insights help create a positive business impact?

# %% [markdown]
# These insights can help create a positive business impact by identifying key hosts with the largest number of listings. Knowing that "Sonder (NYC)" and "Blueground" dominate the market can help in forming strategic partnerships or targeted marketing efforts to leverage their influence. Additionally, understanding the distribution of listings can aid in resource allocation and competitive analysis

# %% [markdown]
# ### Chart-7 : Room Types

# %%
# Room Types
room_types= df.groupby('room_type').size()
room_types
# Out:
# room_type
# Entire home/apt    25409
# Private room       22326
# Shared room         1160
# dtype: int64

# %%
plt.pie(room_types,labels=['Entire home/apt','Private room','Shared room'],shadow=True,autopct='%.2f')
plt.title("Room Types")
# Out:
# Text(0.5, 1.0, 'Room Types')

# %% [markdown]
# #### Why did you pick the specific chart?

# %% [markdown]
# The pie chart was chosen because it effectively displays the proportional distribution of different room types within a dataset. Pie charts are ideal for showing how a whole is divided into various parts, providing a clear visual of the relative sizes of each category.

# %% [markdown]
# #### What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart reveals that the majority of listings are for entire homes/apartments, accounting for 51.97% of the total. Private rooms make up a substantial portion as well, representing 45.66% of the listings. Shared rooms are the least common, comprising only 2.37% of the listings.

# %% [markdown]
# #### Will the gained insights help create a positive business impact?

# %% [markdown]
# These insights can help create a positive business impact by informing business strategies regarding the types of accommodations to focus on. Knowing that entire homes/apartments and private rooms dominate the market can guide investment and marketing efforts towards these popular categories. Additionally, understanding the small market share of shared rooms might suggest a niche opportunity or highlight areas for potential growth and differentiation.

# %% [markdown]
# ### Chart-8 : Top 10 Apartment listings

# %%
apt = df[df['room_type']=='Entire home/apt']
list_apt = apt.groupby(['host_id','host_name','neighbourhood','neighbourhood_group']).size().reset_index(name='apartment').sort_values(by=['apartment'],ascending=False)
list_apt.head(10)
# Out:
#          host_id     host_name       neighbourhood neighbourhood_group  \
# 20219  219517861  Sonder (NYC)  Financial District           Manhattan
# 6452     7503643          Vida          Greenpoint            Brooklyn
# 8434    12243051        Sonder  Financial District           Manhattan
# 20222  219517861  Sonder (NYC)         Murray Hill           Manhattan
# 17840  120762452       Stanley         Murray Hill           Manhattan
# 19908  205031545    Red Awning             Midtown           Manhattan
# 12278   30283594          Kara      Hell's Kitchen           Manhattan
# 17458  107434423    Blueground             Chelsea           Manhattan
# 17635  113805886        Yaacov     Upper East Side           Manhattan
# 12280   30283594          Kara             Midtown           Manhattan
#
#        apartment
# 20219        210
# 6452          52
# 8434          51
# 20222         50
# 17840         49
# 19908         49
# 12278         41
# 17458         37
# 17635         33
# ...

# %%
apt.groupby('neighbourhood_group').size().plot(kind='bar', color=sns.palettes.mpl_palette('Dark2'))
# Out:
# <Axes: xlabel='neighbourhood_group'>

# %% [markdown]
# #### Why did you pick the specific chart?

# %% [markdown]
# The specific chart chosen is a bar chart representing the distribution of Airbnb listings across different neighborhood groups in 2019. It was likely selected because it provides a clear visual comparison of listing counts for each neighborhood, allowing us to identify trends and disparities

# %% [markdown]
# #### What is/are the insight(s) found from the chart?

# %% [markdown]
# **Manhattan Dominance:** Manhattan stands out with the highest number of listings. This suggests that it’s the most popular area for Airbnb rentals.
#
# **Brooklyn as Runner-Up:** Brooklyn follows Manhattan, indicating significant demand there as well.
#
# **Queens, Bronx, and Staten Island:** These neighborhoods have notably fewer listings, implying lower popularity or less active Airbnb activity

# %% [markdown]
# #### Will the gained insights help creating a positive business impact? Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Strategic Focus:** Insights can guide marketing efforts. Focusing on Manhattan and Brooklyn, where demand is high, could yield positive results.
#
# **Expansion Opportunities:** Exploring Queens and Staten Island may lead to growth in untapped markets.

# %% [markdown]
# **Potential Negative Growth:**
#
# Oversaturation Risk: If Airbnb aggressively expands in already popular areas (e.g., Manhattan), it might oversaturate the market, leading to diminishing returns.
#
# Resource Allocation: Investing in less popular neighborhoods (e.g., Bronx) without proper demand analysis could result in negative growth.

# %% [markdown]
# ### Chart-9 : Top 10 Private listings

# %%
PVT=df[df['room_type']=='Private room']
PRVT=PVT.groupby(['host_id','host_name','neighbourhood','neighbourhood_group']).size().reset_index(name='private').sort_values(by=['private'],ascending=False)
PRVT.head(10)
# Out:
#          host_id host_name       neighbourhood neighbourhood_group  private
# 15270  190921808      John      Hell's Kitchen           Manhattan       44
# 14032  137358866    Kazuya            Woodside              Queens       35
# 16311  238321374      Eyal     Upper West Side           Manhattan       32
# 15993  224414117   Gabriel      Hell's Kitchen           Manhattan       30
# 16044  226410657      Nina  Bedford-Stuyvesant            Brooklyn       26
# 16154  230192510      Zach         Fort Greene            Brooklyn       25
# 16396  242962235     Yuval           Ridgewood              Queens       23
# 16549  252604696      Erin             Chelsea           Manhattan       20
# 14668  159091490   Melissa             Gowanus            Brooklyn       17
# 14031  137358866    Kazuya           Sunnyside              Queens       17

# %%
PVT.groupby('neighbourhood_group').size().plot(kind='bar', color=sns.palettes.mpl_palette('Dark2'))
# Out:
# <Axes: xlabel='neighbourhood_group'>

# %% [markdown]
# ####Why did you pick the specific chart?

# %% [markdown]
# The specific chart chosen is a bar chart representing the distribution of private rooms across different neighborhood groups in 2019. It provides insights into the prevalence of private room listings in various areas.

# %% [markdown]
# #### What is/are the insight(s) found from the chart?

# %% [markdown]
# **Brooklyn Dominance:** Brooklyn has the highest proportion of private room listings, accounting for 20.7% of the total listed properties.
#
# **Manhattan Follows:** Manhattan comes next, with 16.3% of the listings being private rooms.
#
# **Queens and Bronx:**
# These neighborhoods have a smaller share of private rooms (6.9% and below).

# %% [markdown]
# #### Will the gained insights help creating a positive business impact? Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Strategic Focus**: Airbnb could strategically target marketing efforts toward Brooklyn and Manhattan due to their popularity for private room rentals.
#
# **Diversification Opportunity:** Exploring Queens and Bronx could lead to growth in untapped markets for private room listings.

# %% [markdown]
# ### Chart-10 Top 10 shared rooms

# %%
shr=df[df['room_type']=='Shared room']
shrd=shr.groupby(['host_id','host_name','neighbourhood','neighbourhood_group']).size().reset_index(name='shared').sort_values(by=['shared'],ascending=False)
shrd.head(10)
# Out:
#        host_id   host_name       neighbourhood neighbourhood_group  shared
# 339   39528519         Max     Lower East Side           Manhattan      23
# 529  119669058     Melissa  Bedford-Stuyvesant            Brooklyn      18
# 651  201015598      Anchor  Bedford-Stuyvesant            Brooklyn      17
# 618  175730239   Baboucarr           Sunnyside              Queens      10
# 663  209386156     Abraham         East Harlem           Manhattan       9
# 727  253906467        Erik      Hell's Kitchen           Manhattan       9
# 686  223087887  Jess & Ana              Corona              Queens       8
# 714  248161322      Sergii            Bushwick            Brooklyn       8
# 292   30509656        Orit         Port Morris               Bronx       8
# 635  187975743     R.Henry      Hell's Kitchen           Manhattan       8

# %% [markdown]
# Obeservation:
#
# Lower East Side in Manhattan, represented by Max, has the highest number of shared room listings with 23 rooms.
# Brooklyn neighborhoods like Bedford-Stuyvesant and Bushwick have a significant presence in shared room listings, with Melissa, Anchor, and Sergii hosting 18, 17, and 8 rooms respectively

# %%
shrd.groupby('neighbourhood_group').size().plot(kind='bar', color=sns.palettes.mpl_palette('Dark2'))
# Out:
# <Axes: xlabel='neighbourhood_group'>

# %% [markdown]
# #### Why did you pick the specific chart?

# %% [markdown]
# The specific chart chosen is a bar chart representing the distribution of shared rooms across different neighborhood groups in New York City. It provides insights into the prevalence of shared room listings.

# %% [markdown]
# #### What is/are the insight(s) found from the chart?

# %% [markdown]
# Manhattan Dominance: Manhattan has the highest count of shared room listings, suggesting it’s the most popular area for this type of accommodation.
#
# Brooklyn Follows: Brooklyn comes next, indicating significant demand for shared rooms.
#
# Queens and Bronx: These neighborhoods have fewer shared room listings, implying lower popularity or less active Airbnb activity in this category.
#
# Staten Island: Staten Island has the fewest shared room listings.

# %% [markdown]
# #### Will the gained insights help creating a positive business impact? Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Strategic Focus: Airbnb could strategically target marketing efforts toward Manhattan and Brooklyn due to their popularity for shared rooms.
#
# Diversification Opportunity: Exploring Queens and Bronx might lead to growth in untapped markets for shared room listings.

# %% [markdown]
# ### Chart-11 : Boxnplot

# %%
df['price'].describe()
# Out:
# count    48895.000000
# mean       152.720687
# std        240.154170
# min          0.000000
# 25%         69.000000
# 50%        106.000000
# 75%        175.000000
# max      10000.000000
# Name: price, dtype: float64

# %% [markdown]
# We also plot a boxplot to understand how the data is spread out for high ranges for the price irrespective of region.

# %%
figsize=(12,8)
sns.boxenplot(x='price',data=df)
# Out:
# <Axes: xlabel='price'>

# %% [markdown]
# #### Why did you pick the specific chart?

# %% [markdown]
# The specific chart is a boxplot that shows the distribution of Airbnb prices. This type of chart is chosen because it effectively highlights the spread and skewness of the data, as well as potential outliers. Boxplots are particularly useful for understanding the central tendency, variability, and the presence of outliers in a dataset.

# %% [markdown]
# #### What is/are the insight(s) found from the chart?

# %% [markdown]
# Price Distribution: The majority of Airbnb listings have prices concentrated in a lower range, indicated by the dense clustering near the y-axis.
#
# Outliers: There are significant outliers in the data, with one listing having a price around $10,000.
#
# Skewness: The distribution of prices is highly skewed to the right, indicating that while most prices are low, there are a few listings with very high prices.

# %% [markdown]
# #### Will the gained insights help create a positive business impact?

# %% [markdown]
# Yes, the insights gained from this chart can help create a positive business impact in several ways:
#
# Pricing Strategy: Understanding the distribution of prices can help hosts set competitive prices. Knowing that most listings are in the lower range, hosts can adjust their prices accordingly to attract more bookings or position themselves in a unique pricing segment.
#
# Outlier Management: Identifying outliers (extremely high-priced listings) can prompt further investigation into why these listings are priced so high and whether they offer unique value propositions or if there are pricing errors.

# %% [markdown]
# ### Chart- 12 : Avg price for one night in neughbourhood group

# %%
# Average price for rooms in nighbourhood group
df1=df[df['minimum_nights']==1]
df2=df1.groupby(['room_type','neighbourhood_group'])['price'].mean().sort_values(ascending=False)
df2.plot(kind='bar',color=[
    '#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd',
    '#8c564b', '#e377c2', '#7f7f7f', '#bcbd22', '#17becf',
    '#1a9850', '#66bd63', '#a6d96a', '#d9ef8b', '#fee08b'
]
)
plt.title('Average Price for rooms in neighbourhood group')
plt.ylabel('Average Daily Price')
plt.xlabel('Neighbourhood Group')
plt.show()
print('List of Average Price per night based on the neighbourhood group')
pd.DataFrame(df2).sort_values(by='room_type')
# Out:
# List of Average Price per night based on the neighbourhood group
#                                           price
# room_type       neighbourhood_group
# Entire home/apt Manhattan            291.784595
#                 Staten Island        266.205128
#                 Brooklyn             202.895245
#                 Bronx                141.541176
#                 Queens               139.036260
# Private room    Manhattan            121.434183
#                 Brooklyn              81.713284
#                 Queens                72.454958
#                 Staten Island         71.394366
#                 Bronx                 69.025862
# Shared room     Manhattan             88.462898
#                 Queens                68.459459
#                 Brooklyn              60.921212
#                 Bronx                 46.711111
#                 Staten Island         21.000000

# %% [markdown]
# #### Why did you pick the specific chart?

# %% [markdown]
# The bar chart depicting the average daily price for different room types across various neighborhood groups was chosen because it clearly illustrates the variation in pricing based on location and accommodation type. This visualization is straightforward, making it easy to compare prices across multiple categories.

# %% [markdown]
# #### What is/are the insight(s) found from the chart?

# %% [markdown]
# Highest Prices: Entire homes/apartments in Manhattan and Staten Island have the highest average daily prices, significantly higher than other areas.
#
# Price Variation: There's a notable price difference between entire homes/apartments and shared/private rooms within the same neighborhood, with entire homes/apartments generally being more expensive.
#
# Affordable Options: Shared and private rooms, especially in the Bronx and Queens, offer more affordable accommodation options.

# %% [markdown]
# #### Will the gained insights help create a positive business impact?

# %% [markdown]
# Targeting Strategies: Airbnb can tailor marketing and pricing strategies to highlight more affordable options in less expensive neighborhoods, appealing to budget-conscious travelers.
#
# Revenue Optimization: Hosts can optimize their pricing based on the competitive landscape, ensuring their listings are attractively priced within their neighborhood and accommodation type.
#
# Customer Segmentation: Airbnb can better segment their customer base, targeting luxury travelers with high-priced Manhattan listings while promoting budget options in other areas. This diversified approach can attract a wider range of guests, enhancing overall platform utilization and satisfaction

# %% [markdown]
# ### Chart-13: Avg price based on neighbourhood

# %% [markdown]
# **Top 15 most expensive neighbourhood**

# %%
prc=df.groupby(['neighbourhood_group','neighbourhood'])['price'].mean().sort_values(ascending=False).head(15)
prc.plot(kind='bar')
prc
# Out:
# neighbourhood_group  neighbourhood
# Staten Island        Fort Wadsworth       800.000000
#                      Woodrow              700.000000
# Manhattan            Tribeca              490.638418
# Brooklyn             Sea Gate             487.857143
# Bronx                Riverdale            442.090909
# Staten Island        Prince's Bay         409.500000
# Manhattan            Battery Park City    367.557143
#                      Flatiron District    341.925000
# Staten Island        Randall Manor        336.000000
# Manhattan            NoHo                 295.717949
#                      SoHo                 287.103352
#                      Midtown              282.719094
# Queens               Neponsit             274.666667
# Manhattan            West Village         267.682292
#                      Greenwich Village    263.405612
# Name: price, dtype: float64

# %% [markdown]
# #### Why did you pick the specific chart?

# %% [markdown]
# The bar chart showing the top 15 most expensive neighborhoods was chosen because it provides a clear and concise comparison of the average prices across different neighborhoods. This type of chart makes it easy to identify the areas with the highest accommodation costs.

# %% [markdown]
# #### What is/are the insight(s) found from the chart?

# %% [markdown]
# Highest Prices: Staten Island neighborhoods (Fort Wadsworth and Woodrow) and Manhattan neighborhoods (Tribeca) have the highest average prices.
#
# Price Variation Across Boroughs: Manhattan dominates the list with multiple neighborhoods, indicating that it is generally more expensive than other boroughs, but Staten Island has some exceptionally high-priced areas.
#
# Affordable High-Price Options: Some traditionally more affordable boroughs like the Bronx and Brooklyn also have neighborhoods with relatively high prices, such as Riverdale and Sea Gate.

# %% [markdown]
# #### Will the gained insights help create a positive business impact?

# %% [markdown]
# Pricing Strategy: Hosts can use this information to set competitive prices in high-demand neighborhoods, potentially increasing their occupancy rates and revenue.
#
# Investment Decisions: Investors and property managers can identify lucrative neighborhoods for new listings or property purchases.
#
# Targeted Marketing: Airbnb can develop marketing campaigns targeting high-end travelers, highlighting the luxury accommodations available in the most expensive neighborhoods.
#
# Customer Segmentation: Understanding the distribution of high-priced neighborhoods helps Airbnb segment their customer base more effectively and tailor their services and recommendations accordingly.

# %% [markdown]
# T**op 15 least expensive neighbourhood**

# %%
prce=df.groupby(['neighbourhood_group','neighbourhood'])['price'].mean().reset_index(name='Avg price').sort_values(by=['Avg price'],ascending=True)
prce.head(15)
# Out:
#     neighbourhood_group   neighbourhood  Avg price
# 181       Staten Island     Bull's Head  47.333333
# 17                Bronx     Hunts Point  50.500000
# 39                Bronx         Tremont  51.545455
# 36                Bronx       Soundview  53.466667
# 199       Staten Island        New Dorp  57.000000
# 3                 Bronx       Bronxdale  57.105263
# 200       Staten Island  New Dorp Beach  57.400000
# 190       Staten Island      Grant City  57.666667
# 184       Staten Island         Concord  58.192308
# 25                Bronx      Mount Eden  58.500000
# 138              Queens          Corona  59.171875
# 47                Bronx        Woodlawn  60.090909
# 4                 Bronx     Castle Hill  63.000000
# 54             Brooklyn    Borough Park  63.066176
# 29                Bronx       Olinville  64.000000

# %%
prce.head(15).plot(kind='bar')
# Out:
# <Axes: xlabel='neighbourhood_group,neighbourhood'>

# %% [markdown]
# #### Why did you pick the specific chart?

# %% [markdown]
# The bar chart showing the top 15 least expensive neighborhoods was chosen because it effectively highlights areas where accommodation costs are the lowest. This visualization makes it easy to compare the affordability of different neighborhoods, which is valuable for budget-conscious travelers.

# %% [markdown]
# #### What is/are the insight(s) found from the chart?

# %% [markdown]
# Lowest Prices: Staten Island and Bronx neighborhoods dominate the list of least expensive areas, with Bull's Head (Staten Island) and Hunts Point (Bronx) being among the lowest.
# Neighborhood Distribution: The Bronx has the highest representation among the least expensive neighborhoods, indicating that it is generally more affordable compared to other boroughs.
# Affordable Options in Multiple Boroughs: Besides the Bronx and Staten Island, there are also affordable neighborhoods in Brooklyn and Queens, such as Borough Park and Corona.

# %% [markdown]
# #### Will the gained insights help create a positive business impact?Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Attracting Budget Travelers: Airbnb can market these neighborhoods to budget-conscious travelers, potentially increasing bookings in these areas.
#
# Optimizing Listings: Hosts in these neighborhoods can optimize their pricing and marketing strategies to highlight affordability, making their listings more attractive to price-sensitive guests.
#
# **There are insights that could lead to negative growth:**
#
# Over-Concentration in Low-Cost Areas: If Airbnb focuses too heavily on promoting the least expensive neighborhoods, it could dilute the platform's appeal to higher-spending travelers and reduce overall revenue.
#
# Devaluation of Listings: Hosts in these low-cost areas might lower their prices further to stay competitive, which could lead to a race to the bottom, impacting their profitability and sustainability.

# %% [markdown]
# ### Chart-14 :Total Number of apt/rooms which are availabel for 365 days

# %%
av=df[df['availability_365']==365]
print('\ntotal number of rooms/apt availabel for 365 days:',av['availability_365'].count())
AV=av.groupby('neighbourhood_group')['neighbourhood'].count().reset_index(name="total").sort_values(by=['total'],ascending=False)
print(AV)
AV.plot(kind='bar', x='neighbourhood_group',y='total',color=['r','y','c','g','b'])
plt.xlabel('neighbourhood_group')
plt.ylabel('Total')
plt.title('365 days availability')
# Out:
# total number of rooms/apt availabel for 365 days: 1295
#   neighbourhood_group  total
# 2           Manhattan    572
# 1            Brooklyn    453
# 3              Queens    204
# 0               Bronx     54
# 4       Staten Island     12
# Text(0.5, 1.0, '365 days availability')

# %% [markdown]
# #### Why did you pick the specific chart?

# %% [markdown]
# I chose the bar chart for its clarity and effectiveness in comparing the availability of rooms across different neighborhoods.

# %% [markdown]
# #### What is/are the insight(s) found from the chart?

# %% [markdown]
# High Availability: Manhattan and Brooklyn have the highest availability, indicating potential for robust long-term rental markets.
#
# Moderate Availability: Queens has a moderate number of long-term rentals, suggesting a balanced market.
#
# Low Availability: The Bronx and Staten Island have the lowest availability, indicating smaller markets.

# %% [markdown]
# #### Will the gained insights help creating a positive business impact? Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Positive Business Impact:**
# Targeted Marketing: Focus marketing efforts on Manhattan and Brooklyn where availability is highest.
#
# Investment Opportunities: Investors might prioritize
#
# Manhattan and Brooklyn for potential high demand.
#
# Resource Allocation: Efficiently allocate resources to neighborhoods with higher rental availability and potential demand.
#
# **Negative Growth Insight:**
#
# Oversaturation Risk: High availability in Manhattan and
#
# Brooklyn might indicate market saturation.
#
# Limited Market: The low availability in the Bronx and
# Staten Island suggests limited growth opportunities in these areas.

# %% [markdown]
# ### Chart-15:Plot Price based on the Availability 365

# %%
plt.figure(figsize=(15,8))
sns.scatterplot(y=df['price'],x=df['availability_365'])
# Out:
# <Axes: xlabel='availability_365', ylabel='price'>

# %% [markdown]
# #### Why did you pick the specific chart?

# %% [markdown]
# I chose the scatter plot because it effectively displays the relationship between two continuous variables: price and availability. This type of chart helps to identify patterns, correlations, and outliers in the data.

# %% [markdown]
# #### What is/are the insight(s) found from the chart?

# %% [markdown]
# Wide Range of Prices: There is a wide range of prices regardless of availability, with some properties priced very high.
#
# High Price Outliers: A few properties are priced significantly higher than the majority, indicating potential luxury or premium listings.
#
# No Strong Correlation: There doesn't appear to be a strong correlation between availability and price, suggesting that other factors might be influencing pricing.

# %% [markdown]
# #### Will the gained insights help creating a positive business impact? Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Market Segmentation: Understanding the distribution of prices can help businesses segment the market and tailor their offerings to different customer groups.
#
# Premium Listings: Identifying high-priced outliers can guide strategies for marketing luxury properties.
#
# Pricing Strategy: The lack of strong correlation suggests pricing strategies can be flexible and based on factors other than availability.

# %% [markdown]
# ### Chart-16:Reviews for neighbourhood groups

# %%
rev=df[df['number_of_reviews']>=50]
revs=rev['neighbourhood_group'].value_counts().sort_values(ascending=False)
revs.plot(kind='bar', color=['r','y','b','g','c'])
plt.xlabel("neighbourhood_group")
plt.ylabel("total reviews")
plt.title('Reviews for neighbourhood groups')
revs
# Out:
# neighbourhood_group
# Brooklyn         3065
# Manhattan        2751
# Queens            997
# Bronx             187
# Staten Island      81
# Name: count, dtype: int64

# %% [markdown]
# #### Why did you pick the specific chart?

# %% [markdown]
# I chose the bar chart because it clearly shows the total number of reviews for each neighborhood group, allowing for easy comparison of customer engagement and feedback across different areas.

# %% [markdown]
# #### What is/are the insight(s) found from the chart?

# %% [markdown]
# High Engagement in Brooklyn and Manhattan: Brooklyn and Manhattan have the highest number of reviews, indicating strong customer engagement and potentially higher demand.
#
# Moderate Engagement in Queens: Queens has a moderate number of reviews, suggesting a decent level of customer interaction.
#
# Low Engagement in Bronx and Staten Island: The Bronx and Staten Island have significantly fewer reviews, indicating lower customer engagement and possibly less market activity.

# %% [markdown]
# #### Will the gained insights help creating a positive business impact? Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Positive Business Impact:**
#
# Focus on High Engagement Areas: Businesses can focus their efforts on Brooklyn and Manhattan, where customer engagement is highest, to maximize returns.
#
# Improvement Opportunities in Queens: Efforts can be made to increase visibility and engagement in Queens, which already has a moderate base.
#
# Customer Feedback Utilization: High review numbers provide valuable feedback for improving services and targeting marketing strategies effectively in Brooklyn and Manhattan.
#
# **Negative Growth Insight:**
#
# Neglect of Low Engagement Areas: Focusing too much on high engagement areas might lead to neglect of potential growth opportunities in the Bronx and Staten Island.
#
# Market Saturation Risk: High engagement in Brooklyn and Manhattan could lead to market saturation, increasing competition and potentially driving down prices.

# %% [markdown]
# ### Chart-17: Top 5 hosts who gets most number of reviews

# %%
name=rev['host_name'].value_counts().sort_values(ascending=False)
name.head(5).plot(kind='bar',color= ['r','y','g','b','c'])
plt.xlabel('Host Name')
plt.ylabel("Reviews")
plt.title('Reviews for Host name')
# Out:
# Text(0.5, 1.0, 'Reviews for Host name')

# %% [markdown]
# host name can be same for diffent category thats why we can't assume that this insight is correct. let's find this using host_id as host_id has the unique value

# %%
# Reviews for host_id
hostid=rev.groupby(['host_id','host_name'])['host_id'].value_counts().sort_values(ascending=False)
hostid.head(5).plot(kind='bar', color=['r','y','g','b','c'])
hostid.head(5)
# Out:
# host_id   host_name
# 6885157   Randy                             12
# 35524316  Yasu & Akiko                      11
# 16677326  Alex And Zeena                    11
# 344035    Brooklyn&   Breakfast    -Len-    11
# 17555570  Yan                               10
# Name: count, dtype: int64

# %% [markdown]
# #### Why did you pick the specific chart?

# %% [markdown]
# The chart highlights the five hosts (identified by their host_id and host_name) with the highest number of reviews.
# These hosts are likely popular and active in the short-term rental market, as reflected by the volume of reviews they’ve received.
# This insight can help new or less-reviewed hosts understand the level of competition and aspire to improve their services or property offerings

# %% [markdown]
# #### What is/are the insight(s) found from the chart?

# %% [markdown]
# Marketing Strategies: Businesses can learn from successful hosts by analyzing their marketing tactics, guest engagement, and property management.
#
# Quality Improvement: High-review hosts likely provide excellent guest experiences. Others can emulate their practices to enhance guest satisfaction.
#
# Pricing Optimization: Popular hosts may have optimized pricing strategies. New hosts can adjust their rates based on this insight.

# %% [markdown]
# #### Will the gained insights help creating a positive business impact? Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Competition Pressure: New hosts might struggle to compete with established ones. They need to differentiate themselves to gain reviews.
#
# Quality Consistency: High-review hosts must maintain quality consistently. A drop in service quality could lead to negative growth.
#
# Market Saturation: If too many hosts follow the same strategies, it could saturate the market, affecting overall growth.

# %% [markdown]
# # **5. Solution to Business Objective**

# %% [markdown]
# We have find out the Top 15 neighbourhoods where number of booking is high, we can focus on those areas for marketting campaigns and advertisements for maximize booking and reduce marketting cost by redcing the focus areas.
#
# Most of the guests doesn't prefer shared rooms rather choose entire home/apt and private room. Manhattan and Brooklyn are most demanded neighbourhood groups.
#
# Most subscribed booking price is come within the bracket of $10-400 where almost 95% booking happens as well as most reviews are also given by these guests. One more thing Private room and Entire home/apt gives most number of reviews.
#
# Maximum listings done by a top hosts are also concentrated in Manhattan and Brooklyn like higher prices and most bookings.
#
# We can say that hosts are also inclined to Manhattan and Brooklyn due to higher price realisation and more booking as we know from earlier charts; so we can ask more comission from hosts here and realise more profit.

# %% [markdown]
# # **Conclusion:**

# %% [markdown]
# 1. Manhattan has the most number of listing follwed by Brooklyn where Staten Island has the least number of Airbnb listing.
# 2. Williamsburg and Bedford-Stuyvensant from Brooklyn has more number of listing that the others.
# 3.  Richmondtown and New Dorp from Staten Island has least number of listing than the others.
# 4. Entire home/apartment listings are the most prevalent, followed by private rooms, with shared rooms being the least common among Airbnb listings.
# 5. Financial district neighbourhood of Manhattan has the more number of Apartments also Manhattan and brooklyn may be traveller choice for the Apartments
# 6. Hell's Kitchen in Manhattan appears to have the highest number of listings for private rooms, but Brooklyn has the more number of listing for private rooms
# 7. There more number listed for the shared room in Manhattan.
# 8. Prices are varies from 0$-10000$,there are diiferent price rate for each neighbourhood_groups.
# 9. For One Night Manhattan are little expensive for travellers or visitors.
# 10.The highest average prices  are observed in Fort Wadsworth (Staten Island) while the most affordable areas include Hunts point (Queens) and Bull's Head (Staten Island).
# 11. Manhattan offers the highest number of rooms/apartments available for 365 days, followed by Brooklyn, Queens, Bronx, and Staten Island, in descending order.
# 12. Brooklyn and Manhattan have the highest number of popular listings where thr Bronx and Staten Island have fewer listings compared to the other boroughs.
# 13. Randy,Yasu & Akikom ,Alex And Zeena are most popular hosts in the Airbnb dataset

# %% [markdown]
# ## ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
